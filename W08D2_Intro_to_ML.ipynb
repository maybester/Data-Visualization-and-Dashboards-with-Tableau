# %% [markdown]
# <a href="https://colab.research.google.com/github/maybester/Data-Visualization-and-Dashboards-with-Tableau/blob/main/W08D2_Intro_to_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # W08D2 Introduction to Machine Learning
#
#  - Instructor: Jeremy Eng
#  - Original notebook by: Socorro Dominguez

# %% [markdown]
# ## Agenda
# 1. Machine Learning
#     - Supervised vs. Unsupervised Learning
# 2. Supervised Learning
#     - `X` and `y`
#     - Regression vs. Classification
#     - The golden rule: train/test split
# 3. Simple Linear Regression
# 4. Multiple Linear Regression
# 5. Polynomial Regression

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ## Definition of ML / What is ML?
#
# Seen as a subset of AI. ML algorithms build a model based on sample data (training data), in order to make predictions without being explicitly programmed to do so.
#
# A field of study that gives computers the ability to learn without being explicitly programmed.
# – Arthur Samuel (1959)
#
# - **Example**: feeding a dog
#     - No ML: always feed dog at 8:00 am, 1:00 pm, and 6:00 pm.
#     - ML: use data on when dog has been hungry in the past to predict the optimal times to feed dog.
#
# - Other examples of ML?

# %% [markdown]
# # Types of Machine Learning: Supervised and Unsupervised

# %% [markdown]
# ## Machine Learning: Supervised Learning
# - In supervised learning, we have a set of observations (__*X*__) with an associated target (__*y*__)
# - We wish to find a model function that relates __*X*__ to __*y*__
# - Then use that model function to predict future observations
#
#  ![sup_learning.png](data:image/png;base64,...)

# %% [markdown]
# ## Machine Learning: Unsupervised Learning
# - We have __*X*__ (the data) but no __*y*__ (associated target)
#
#  ![unsup_learning.png](data:image/png;base64,...)

# %% [markdown]
# # Types of Supervised Learning: Regression and Classification

# %% [markdown]
# ## Classification vs. Regression
#
# * Classification problems: predicting among two or more categories, also known as classes
#     - Predict whether a patient has a liver disease or not
#     - Predict whether the letter grade of a student (A, B, C, D or F)
# * Regression problem: predicting a continuous (in other words, a number) value
#     - Predict house prices
#     - Predict someone's age from their photo

# %% [markdown]
# ## The golden rule
# - When you're doing supervised learning, now that you've identified **X** and **y**
# - **You need to split your data into train and test**
# - **You only work with the training data**
#
# ### Why?
# - We want to "hide" some data while training, so that we can later evaluate our trained model on **unseen data**.
#     - Analogy: studying for a test.
# - The ability to evaluate on unseen data is very important. It allows to make decisions like which model is best and/or which features should be included/dropped.
# - Compare this to the statistical modelling earlier, where we didn't split our data.
#     - There, we were more interested in finding the relationships in our data.
#     - For ML, we are more interested in making predictions on future data.

# %% [markdown]
# ## The big picture
# - We train using the **training data**
# - We test what is learned by the model on the **test data**
# - We have two scores: **training** vs. **test**
# - Example:
#     - Model predicts apple or banana with a 95% training accuracy (accuracy on the training data)
#     - Model predicts apple or banana with a 90% testing accuracy (accuracy on the testing data)
#
# ### Which matters more?
# - It doesn't matter how good our **training score** is because the **test score is what matters**
# - Good models that generalize well though will have **similar training and testing scores**
# - Typically training scores are higher than testing scores.
# - The difference between the training and testing scores is called **generalization error**.
#
# **We want to pick models that generalize well to unseen data**

# %% [markdown]
# ## The fundamental tradeoff
#
# - Different ML models can different amounts of "complexity".
#
# | Model | Training Score relative to Test Score | Performance |
# |:-|:-|:-|
# |Too Simple|Low training score and low test score|Underfit|
# | Too Complex|High training score compared to test score| Overfit |
#
#
# - Models that have **extremely high training scores** (that are too good to be true) that are **highly complex** that learned very complex relationships in the training data **can be overfit**
#     - Modeled **noise** in the training data instead of a relationship/pattern.
# - On the other hand, models that have **low training scores** that are **very simple** may not have learned the necessary relationships in the training data needed to predict well on unseen data; they are **underfit**
#
# ![](tradeoff.png)

# %% [markdown]
# ![img](https://miro.medium.com/max/2250/1*_7OPgojau8hkiPUiHoGK_w.png)

# %% [markdown]
# ## The fundamental tradeoff (part 2)
# In the "bias-variance" language
#
# - **Bias**
#     - Bias refers to the error introduced by approximating a real-world problem with a simplified model. A model with high bias error tends to make simplistic assumptions about the underlying data, leading to underfitting.
#     - An underfit model is not able to capture the true patterns and relationships in the data, resulting in poor performance.
# - **Variance**
#     - Measures the variability of a model for different training datasets. A model with high variance is sensitive to fluctuations in the training data and tends to overfit.
#     - An overfit model has memorized the training data to a great extent, but it fails to generalize well to unseen data, leading to poor performance on test or validation datasets.
#
# - Goal is to find a model that balances bias and variance, so the total error is minimized.

# %% [markdown]
# ![img](https://miro.medium.com/max/2250/1*_7OPgojau8hkiPUiHoGK_w.png)

# %% [markdown]
# ![](bias_variance_tradeoff.png)

# %% [markdown]
# ## Errors in Prediction
# - **Approximation error**
#     - The difference between the true function that maps input data to output values and the approximated function that a learning algorithm or model produces.
# - **Estimation error**
#     - The difference between the true values of parameters and their estimated values obtained from learning algorithm.
# - **Optimization error**
#     - Error that occurs during the process of optimization. More on this later when you learn about loss functions and gradient descent.

# %% [markdown]
# ## Linear Regression
#
# - Linear regression is one of the most basic and popular ML/statistical techniques.
# - Used as a predictive model
# - Assumes a linear relationship between the dependent variable (which is the variable we are trying to predict/estimate, **y**) and the independent variable/s (input variable/s used in the prediction, **X**)
#
# ### Let's start with **simple** linear regression
# - Only one independent/input variable is used to predict the dependent variable.

# %% [markdown]
# ## Simple Linear Regression
#
# $$\hat{y} = wx + b$$
#
# $\hat{y}$ = Dependent variable
#
# $b$ = Constant
#
# $w$ = Coefficients
#
# $x$ = Independent variable

# %% [markdown]
# ## Multiple Linear Regression
# - Many $x$'s and $w$'s
#
# $$\hat{y} = w_1x_1 + w_2x_2 + ... + b$$
#
# - The larger the relative value of $w_i$, the more influence $x_i$ has on the target $\hat{y}$

# %% [markdown]
# ## Matrix representation
#
# - $\hat{y}$ is the linear function of features $x$ and weights $w$.
#
# $$\hat{y} = w^Tx + b$$
#
# - $\hat{y} \rightarrow$ prediction
# - $w \rightarrow$ weight vector
# - $b \rightarrow$ bias
# - $x \rightarrow$ features
#
# $$\hat{y} = \begin{bmatrix}w_1 & w_2 & \cdots & w_d\end{bmatrix}\begin{bmatrix}x_1 \\ x_2 \\ \vdots \\ x_d\end{bmatrix} + b$$

# %% [markdown]
# ## Matrix representation for multiple predictions
#
# $$\hat{y} = w^TX + b$$
#
#
# $$\hat{y} = \begin{bmatrix}w_1 & w_2 & \cdots & w_d\end{bmatrix}\begin{bmatrix}x^{(1)}_1 & x^{(2)}_1 & \ldots &x^{(n)}_1\\ x^{(1)}_2 & x^{(2)}_2 & \ldots & x^{(n)}_2 \\ \vdots & \vdots & \ldots \\ x^{(1)}_d & x^{(2)}_d & \ldots & x^{(n)}_d\end{bmatrix} + b$$

# %% [markdown]
# ## Let's try it!
# Let's start simple and imagine we have a dataset of Height and Weight. Suppose we are interested in predicting weight from height.
# - Height is our "feature" and Weight is our "target".

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('weight-height.csv', usecols = ['Height', 'Weight'])

df.head()
# Out:
#       Height      Weight
# 0  73.847017  241.893563
# 1  68.781904  162.310473
# 2  74.110105  212.740856
# 3  71.730978  220.042470
# 4  69.881796  206.349801

# %% [markdown]
# ### Review:
# - **Is this supervised or unsupervised learning? Why?**
# - **Is this a regression or classification problem? Why?**

# %%
from sklearn.linear_model import LinearRegression

X = df['Height']
y = df['Weight']

lr_model = LinearRegression()

# %%
lr_model.fit(X, y) #normally this works fine, but will give error when only one feature.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 lr_model.fit(X, y)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# ...

# %%
df['Height'].values
# Out:
# array([73.84701702, 68.78190405, 74.11010539, ..., 63.86799221,
#        69.03424313, 61.94424588])

# %%
df['Height'].values.reshape(-1,1)
# Out:
# array([[73.84701702],
#        [68.78190405],
#        [74.11010539],
#        ...,
#        [63.86799221],
#        [69.03424313],
#        [61.94424588]])

# %%
X = df['Height'].values.reshape(-1,1) #special case when you only have 1 feature

lr_model.fit(X,y)
# Out:
# LinearRegression()

# %%
lr_model.coef_
# Out:
# array([7.71728764])

# %%
lr_model.intercept_
# Out:
# -350.73719181213676

# %% [markdown]
# See `sklearn` documentation for a full list of methods/attributes for a sklearn class (model):
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
# Visualize results
plt.scatter(X, y, alpha=0.1); #alpha for transparency
plt.plot(X, (lr_model.coef_*X)+lr_model.intercept_, c='black')

# %%
#make predictions using .predict()

new_height = np.array([70.56]).reshape(-1,1)
pred_weight = lr_model.predict(new_height)
pred_weight
# Out:
# array([193.79462412])

# %%
lr_model.score(X, y) #R^2 score tells us how well the model fits our data
# Out:
# 0.8551742120609958

# %% [markdown]
# ## Did we forget to do anything?

# %% [markdown]
# - Remember, we want to evaluate our model on data it has **NOT** seen before.
# - **You need to split your data into train and test**
# - Most common way is to use `train_test_split` in `sklearn`
#     - Shuffles the data first and then splits it
# - 80/20, 75/25, 70/30 are common splits (train/test)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=14)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (10000, 1)
# (8000, 1)
# (2000, 1)

# %%
print(y.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (10000,)
# (8000,)
# (2000,)

# %%
lr_model.fit(X_train,y_train) #notice only fit using training data
# Out:
# LinearRegression()

# %%
R2_train = lr_model.score(X_train,y_train)
print(R2_train)

R2_test = lr_model.score(X_test,y_test)
print(R2_test)
# Out:
# 0.8555723458347143
# 0.8535663387111578

# %% [markdown]
# ### Are we Underfitting? Overfitting?
#
# ### Should we increase or decrease model complexity?

# %% [markdown]
# ## Polynomial regression
#
# ### Non-linear regression motivation
# - Linear regression might seem rather limited.
# - What if the true relationship between the target and the features is non-linear?
# - A more complex model than linear regression
#
# **We still use the linear regression framework, but create quadratic, cubic etc. features**

# %%
from sklearn.preprocessing import PolynomialFeatures

deg = 3
poly_feats = PolynomialFeatures(degree=deg, include_bias=False)

X_deg = poly_feats.fit_transform(X)

X_poly_feat_names = poly_feats.get_feature_names_out(['x'])

df_X_deg = pd.DataFrame(X_deg, columns=X_poly_feat_names)
df_X_deg.head()
# Out:
#            x          x^2            x^3
# 0  73.847017  5453.381922  402715.987625
# 1  68.781904  4730.950324  325403.771243
# 2  74.110105  5492.307721  407035.504061
# 3  71.730978  5145.333263  369079.789145
# 4  69.881796  4883.465393  341265.331673

# %%
X_deg_train, X_deg_test, y_train, y_test = train_test_split(df_X_deg, y, test_size=0.2, random_state=14)

lr_poly = LinearRegression()

lr_poly.fit(X_deg_train, y_train)

lr_poly.coef_
# Out:
# array([-1.92547270e+02,  3.01231829e+00, -1.50612612e-02])

# %%
lr_poly.intercept_
# Out:
# 4074.692256999776

# %%
## FROM PREVIOUS LINEAR REGRESSION MODEL
R2_train = lr_model.score(X_train,y_train)
print(f'R2 train for linear: {R2_train}')

R2_test = lr_model.score(X_test,y_test)
print(f'R2 test for linear: {R2_test}')
# Out:
# R2 train for linear: 0.8555723458347143
# R2 test for linear: 0.8535663387111578

# %%
## Polynomial model
R2_train_poly = lr_poly.score(X_deg_train,y_train)
print(f'R2 train for poly: {R2_train_poly}')

R2_test_poly = lr_poly.score(X_deg_test,y_test)
print(f'R2 test for poly: {R2_test_poly}')
# Out:
# R2 train for poly: 0.8579338742373415
# R2 test for poly: 0.8566680422975246

# %% [markdown]
# We see a slight improvement in R2 test for the polynomial model...

# %% [markdown]
# ## Multiple Linear Regression
#
# Next, let's look at an example where we have multiple features. Let's load the California Housing Data Set
#
# [Documentation](https://scikit-learn.org/stable/datasets/real_world.html#california-housing-dataset)

# %%
from sklearn.datasets import fetch_california_housing

X, y = fetch_california_housing(return_X_y=True, as_frame=True)

X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: MedHouseVal, dtype: float64

# %% [markdown]
# ## Concept check
# - Regression or Classification problem?
# - What are the features?
# - What is the target?

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (20640, 8)
# (16512, 8)
# (4128, 8)

# %%
print(y.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (20640,)
# (16512,)
# (4128,)

# %% [markdown]
# ## Training the model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr_intercept = lr.intercept_
lr_intercept
# Out:
# -36.85856910680134

# %%
lr_coeffs = lr.coef_
lr_coeffs
# Out:
# array([ 4.33333407e-01,  9.29324337e-03, -9.86433739e-02,  5.93215487e-01,
#        -7.56192502e-06, -4.74516383e-03, -4.21449336e-01, -4.34166041e-01])

# %%
words_coeffs_df = pd.DataFrame(data = lr_coeffs.T, index = X_train.columns, columns=['Coefficients'])
words_coeffs_df
# Out:
#             Coefficients
# MedInc          0.433333
# HouseAge        0.009293
# AveRooms       -0.098643
# AveBedrms       0.593215
# Population     -0.000008
# AveOccup       -0.004745
# Latitude       -0.421449
# Longitude      -0.434166

# %% [markdown]
# ## Model Predictions

# %%
X.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
new_house = np.array([4, 30, 5, 2, 1400, 3, 35.5, -119.5]).reshape(1,-1)
price_pred = lr.predict(new_house)
price_pred
# Out:
# C:\Users\enger\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.74334426])

# %%
df_new_house = pd.DataFrame(new_house, columns=X.columns)
price_pred = lr.predict(df_new_house)
price_pred
# Out:
# array([2.74334426])

# %% [markdown]
# ## Model Evaluation
# Ok, we've trained a model that can make price predictions. Does it give good predictions? Bad? How can we evaluate it?
#
# Are we underfitting? Overfitting?
#
# Remember, we want a model that does well on the **testing** data!

# %%
R2_lr_train = lr.score(X_train,y_train)
print(f'R2 lr train: {R2_lr_train}')

R2_lr_test = lr.score(X_test,y_test)
print(f'R2 lr test: {R2_lr_test}')
# Out:
# R2 lr train: 0.6088968118672872
# R2 lr test: 0.5943232652466205

# %% [markdown]
# Perhaps underfitting. Try a more complex model?

# %%
deg = 2  #increase this for increased complexity
poly_feats = PolynomialFeatures(degree=deg, include_bias=False)

X_deg = poly_feats.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_deg, y, test_size=0.2, random_state=0)

lr_poly = LinearRegression()
lr_poly.fit(X_train, y_train)

R2_lr_poly_train = lr_poly.score(X_train,y_train)
print(f'R2 lr_poly train: {R2_lr_poly_train}')

R2_lr_poly_test = lr_poly.score(X_test,y_test)
print(f'R2 lr_poly test: {R2_lr_poly_test}')
# Out:
# R2 lr_poly train: 0.6864099059497207
# R2 lr_poly test: -1.1195872494337302

# %% [markdown]
# Now we are overfitting! Using 44 features instead of the original 8

# %%
pd.DataFrame(X_deg, columns=poly_feats.get_feature_names_out()).head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude   MedInc^2  MedInc HouseAge  ...  Population^2  \
# 0    -122.23  69.308955         341.3332  ...      103684.0
# 1    -122.22  68.913242         174.3294  ...     5764801.0
# 2    -122.24  52.669855         377.3848  ...      246016.0
# 3    -122.25  31.844578         293.4412  ...      311364.0
# 4    -122.25  14.793254         200.0024  ...      319225.0
#
#    Population AveOccup  Population Latitude  Population Longitude  AveOccup^2  \
# 0           822.888889             12197.36             -39358.06    6.530864
# ...

# %% [markdown]
# Better performance be achieved by:
# - Finding a model somewhere in between (in terms of complexity)
# - Feature engineering or dropping out features.
# - Tuning "hyper-parameters" (more on this later).
# - Others...
#
# Here's an example of another regression model:

# %%
from sklearn.tree import DecisionTreeRegressor #will learn about this learning algorithm later

dt = DecisionTreeRegressor(max_depth=10) #max_depth is a "hyper-parameter" (can control complexity)
dt.fit(X_train, y_train)

R2_dt_train = dt.score(X_train,y_train)
print(f'R2 dt train: {R2_dt_train}')

R2_dt_test = dt.score(X_test,y_test)
print(f'R2 dt test: {R2_dt_test}')
# Out:
# R2 dt train: 0.8515466715056017
# R2 dt test: 0.6723044550987749

# %% [markdown]
# # Summary
# - Machine Learning gives computers the ability to learn without being explicitly programmed.
# - Two main types of ML:
#     - Supervised and Unsupervised (others like reinforcement learning, semi-supervised learning)
# - Within **supervised learning**, there are two main types:
#     - Regression and Classification
# - We want models that perform well on data they have NOT seen before.
#     - Train/test splitting
# - Tradeoff between bias and variance (model complexity)
#     - Want to maximize test score (minimize test error).
# - Linear Regression (simple) vs Polynomial regression (more complex)

# %% [markdown]
# ## Bonus: Classification Example
#
# Below is an example of using ML to predict if a tumor is malignant (0) or benign (1), based on tumor features.
#
# [Documentation](https://scikit-learn.org/stable/datasets/toy_dataset.html#breast-cancer-dataset)

# %%
from sklearn.datasets import load_breast_cancer

X, y = load_breast_cancer(return_X_y=True, as_frame=True)

X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
y.value_counts()
# Out:
# 1    357
# 0    212
# Name: target, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

acc_train = log_reg.score(X_train,y_train)
print(f'acc train: {acc_train}')

acc_test = log_reg.score(X_test,y_test)
print(f'acc test: {acc_test}')
# Out:
# acc train: 0.9538461538461539
# acc test: 0.9473684210526315
# C:\Users\enger\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.tree import DecisionTreeClassifier

dt_class = DecisionTreeClassifier(max_depth=10) #change to vary complexity of decision tree
dt_class.fit(X_train, y_train)

acc_train = dt_class.score(X_train,y_train)
print(f'acc train: {acc_train}')

acc_test = dt_class.score(X_test,y_test)
print(f'acc test: {acc_test}')
# Out:
# acc train: 1.0
# acc test: 0.9122807017543859
